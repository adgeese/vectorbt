# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install vectorbt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.9/526.9 KB 7.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 KB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 31.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.1
#     Uninstalling numpy-1.23.1:
#       Successfully uninstalled numpy-1.23.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# freqtrade develop requires ccxt>=1.77.29, but you have ccxt 1.76.65 which is incompatible.
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# ...

# %%
import vectorbt as vbt

price = vbt.YFData.download('BTC-USD').get('Close')

pf = vbt.Portfolio.from_holding(price, init_cash=100)
pf.total_profit()
# Out:
# 3494.676790302044

# %%
import numpy as np
import pandas as pd

# %%
# Entry EMA5 Crossover EMA11
# Exit EMA5 Crossunder EMA11
fast_ema = vbt.IndicatorFactory.from_talib('EMA').run(price, 5)
slow_ema = vbt.IndicatorFactory.from_talib('EMA').run(price, 11)
#old_fast_ma = vbt.MA.run(price, 5)
#old_slow_ma = vbt.MA.run(price, 11)
entries = fast_ema.close_crossed_above(slow_ema)
exits = fast_ema.close_crossed_below(slow_ema)
direction = ['longonly', 'shortonly']  # per column

#vbt.talib("MA").run(price).plot().show()

#vbt.talib("MA").run(price).plot().show()

#print(old_fast_ma)
#print(entries)

signals = np.full((len(price.index)), 0., dtype=np.float_)

#entries

signals[np.flatnonzero(price.index.isin(entries))] += 100.
#signals[np.flatnonzero(price.index.isin(exits))] += -100.
#signals /= 100.  # TA-Lib functions have output in increments of 100

signals
np.count_nonzero(signals)

#pf = vbt.Portfolio.from_signals(price, entries, exits, direction=direction, init_cash=100)
#pf.total_profit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11896/1739782724.py in <module>
#      20 #entries
#      21
# ---> 22 signals[np.flatnonzero(price.index.isin(entries))] += 100.
#      23 #signals[np.flatnonzero(price.index.isin(exits))] += -100.
#      24 #signals /= 100.  # TA-Lib functions have output in increments of 100
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in isin(self, values, level)
#    6215         if level is not None:
#    6216             self._validate_index_level(level)
# -> 6217         return algos.isin(self._values, values)
#    6218
#    6219     def _get_string_slice(self, key: str_t):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     483     if not isinstance(comps, np.ndarray):
#     484         # i.e. Extension Array
# ...
